# %% [markdown]
# # World_happiness_report

# %%
#importing the required libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#importing the dataset
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
#checking the type of file
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#to check all the columns that are present
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.all()
# Out:
# Country                           True
# Region                            True
# Happiness Rank                    True
# Happiness Score                   True
# Standard Error                    True
# Economy (GDP per Capita)         False
# Family                           False
# Health (Life Expectancy)         False
# Freedom                          False
# Trust (Government Corruption)    False
# Generosity                       False
# Dystopia Residual                 True
# dtype: bool

# %%
#checking the statistical value
df.isnull().sum()

#every column does not have null values
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
#Exploring the data 

#1st we use Scatter plot
sns.scatterplot(x="Country",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Dystopia Residual'>

# %% [markdown]
# we can see that we are getting a mixed report

# %%
sns.scatterplot(x="Region",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Dystopia Residual'>

# %% [markdown]
# we can see from the plot that few countries have Dystopia

# %%
sns.scatterplot(x="Happiness Rank",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Happiness Score",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Standard Error",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Dystopia Residual'>

# %% [markdown]
# The range is more darker from 0.03 to 0.05

# %%
sns.scatterplot(x="Economy (GDP per Capita)",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Family",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Dystopia Residual'>

# %% [markdown]
# As we can see from the plot the range is from 0.8 to 1.3

# %%
sns.scatterplot(x="Health (Life Expectancy)",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Freedom",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Trust (Government Corruption)",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Dystopia Residual'>

# %% [markdown]
# From the graph we could see that it's more darker in the range from 0.0 to 0.2

# %%
sns.scatterplot(x="Generosity",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Dystopia Residual'>

# %% [markdown]
# From the plot we can see the ranges are from 0.1 to 0.4

# %%
#Checking the Correlation between the columns

# %% [markdown]
# # Correlation:

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
#sorting values in ascending order
df.corr()['Dystopia Residual'].sort_values()
# Out:
# Happiness Rank                  -0.521999
# Generosity                      -0.101301
# Trust (Government Corruption)   -0.033105
# Health (Life Expectancy)         0.018979
# Economy (GDP per Capita)         0.040059
# Freedom                          0.062783
# Standard Error                   0.083981
# Family                           0.148117
# Happiness Score                  0.530474
# Dystopia Residual                1.000000
# Name: Dystopia Residual, dtype: float64

# %% [markdown]
# # Correlation using the heatmap:

# %%
#Using heatmap to easily view large data
import matplotlib.pyplot as plt
#setting the size of the plot to be displayed
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor="yellow",fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Outcome of Correlation:

# %% [markdown]
# All the columns of the dataset is positively correlated with the target column.
#
# 1. Happiness Rank has 52 percent correlation with the target column which can be considered as a good bond.
# 2. Happiness Score has 53 percent correlation with the target column which can be considered as a good bond.
# 3. Standard Error has 8 percent correlation with the target column which can be considered as a weak bond.
# 4. Economy(GDP per Capita) has 4 percent correlation with the target column which can be considered as a weak bond.
# 5. Family has 15 percent correlation with the target column which can be considered as a weak bond.
# 6. Health(Life Expectancy) has 2 percent correlation with the target column which can be considered as a weak bond.
# 7. Freedom has 6 percent correlation with the target column which can be considered as a weak bond.
# 8. Trust(Government Corruption) has 3 percent correlation with the target column which can be considered as a weak bond.
# 9. Generosity has 10 percent correlation with the target column which can be considered as a weak bond.
# Max correlation: Happiness Score
#
# Min correlation: Health(Life Expectancy)

# %% [markdown]
# Describing the Datasets:

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables summary")
plt.show()

# %% [markdown]
# # Outcome of describe of Datasets:

# %% [markdown]
# # From the above plotting we are determining mean, standard deviation, minimum and maximum value of each column.
#
# Total number of rows and & columns in the datasets: 158 rows 12 columns
#
# Happiness Rank
#
# Happiness Score
#
# 1.Mean=5.380000 2.std=1.150000 3.min_value=2.840000 4.max_value=7.590000
#
# Standard Error
#
# 2.Mean=0.050000 2.std=0.020000 3.min_value=0.020000 4.max_value=0.140000
#
# Economy(GDP per capita)
#
# 3.Mean=0.850000 2.std=0.400000 3.min_value=0.000000 4.max_value=1.690000
#
# Family
#
# 4.Mean=0.990000 2.std=0.270000 3.min_value=0.000000 4.max_value=1.400000
#
# Health(Life Expectancy)
#
# 5.Mean=0.630000 2.std=0.250000 3.min_value=0.000000 4.max_value=1.030000
#
# Freedom
#
# 6.Mean=0.430000 2.std=0.150000 3.min_value=0.000000 4.max_value=0.670000
#
# Trust(Government Corruption)
#
# 7.Mean=0.140000 2.std=0.120000 3.min_value=0.000000 4.max_value=0.550000
#
# Generosity
#
# 8.Mean=0.240000 2.std=0.130000 3.min_value=0.000000 4.max_value=0.800000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# From the above code we can have the columns datatype and the memory used by the dataframe

# %% [markdown]
# # Outliers Checking:

# %%
#using boxplot
import warnings
warnings.filterwarnings('ignore')

# %%
#plotting each individual columns

collist=['Happiness Rank','Happiness Score','Standard Error','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]].values,color='red')
    plt.tight_layout()

# %% [markdown]
# # Skewness

# %%
#checking the skewness of the dataset
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# Skewness threshold is taken is +/0.65. Columns which are having skewness:
#
# 1. Standard Error
# 2. Trust (Government Corruption)
# 3. Generosity

# %% [markdown]
# # Normal Distribution Curve:

# %%
sns.distplot(df["Happiness Rank"])
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %%
sns.distplot(df["Happiness Score"])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
sns.distplot(df["Standard Error"])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(df["Economy (GDP per Capita)"])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df["Family"])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df["Health (Life Expectancy)"])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df["Freedom"])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df["Trust (Government Corruption)"])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df["Generosity"])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %% [markdown]
# # Data Preprocessing:

# %% [markdown]
# Data Cleaning:

# %%
df.corr()['Dystopia Residual']
# Out:
# Happiness Rank                  -0.521999
# Happiness Score                  0.530474
# Standard Error                   0.083981
# Economy (GDP per Capita)         0.040059
# Family                           0.148117
# Health (Life Expectancy)         0.018979
# Freedom                          0.062783
# Trust (Government Corruption)   -0.033105
# Generosity                      -0.101301
# Dystopia Residual                1.000000
# Name: Dystopia Residual, dtype: float64

# %%
delete=pd.DataFrame([["0.083981","Standard Error","No","Alot"],["0.040059","Economy (GDP per Capita)","No","Alot"]],columns=["Correlation with Target","Column name","Normalised","Outliers"])
delete
# Out:
#   Correlation with Target               Column name Normalised Outliers
# 0                0.083981            Standard Error         No     Alot
# 1                0.040059  Economy (GDP per Capita)         No     Alot

# %% [markdown]
# Setting the Threshold of correlation +/-0.1

# %%
df=df.drop(["Standard Error","Economy (GDP per Capita)"],axis=1)
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score   Family  Health (Life Expectancy)  Freedom  \
# 0              7.587  1.34951                   0.94143  0.66557
# ...

# %% [markdown]
# # Removing Outliers:

# %% [markdown]
# Using Z-Score Technique

# %%
from scipy.stats import zscore
import numpy as np
threshold=3
mean=np.mean(collist)
std=np.std(collist)

for i in collist:
    z_score= (i -mean)/std
    if np.abs(z_score)>threshold:
        outliers.append(y)
return outliers
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5848/3332439161.py in <module>
#       2 import numpy as np
#       3 threshold=3
# ----> 4 mean=np.mean(collist)
#       5 std=np.std(collist)
#       6
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# F:\computer\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims, where)
#    3417             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3418
# -> 3419     return _methods._mean(a, axis=axis, dtype=dtype,
#    3420                           out=out, **kwargs)
#    3421
#
# F:\computer\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     176             is_float16_result = True
#     177
# --> 178     ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# ...

# %%
#to find the length
len(np.where(z>3)[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5848/283834747.py in <module>
#       1 #to find the length
# ----> 2 len(np.where(z>3)[0])
#
# NameError: name 'z' is not defined

# %%
z.iloc[4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5848/3321950707.py in <module>
# ----> 1 z.iloc[4]
#
# NameError: name 'z' is not defined

# %%
df_new=df[(z<3).all(axis=1)]
print("Old Dataframe",df.shape)
print("New Dataframe",df_new.shape)
print("total_dropped_rows",df.shape[0] - df_new.shape[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5848/3803145654.py in <module>
# ----> 1 df_new=df[(z<3).all(axis=1)]
#       2 print("Old Dataframe",df.shape)
#       3 print("New Dataframe",df_new.shape)
#       4 print("total_dropped_rows",df.shape[0] - df_new.shape[0])
#
# NameError: name 'z' is not defined

# %% [markdown]
# # Percentage Data Loss

# %%
loss_percent=(768-716)/768*100
print(loss_percent,'%')
# Out:
# 6.770833333333333 %

# %% [markdown]
# checking wheather how much outliers are there. if outliers there help in testing the model.

# %% [markdown]
# # Model without outliers is df and model with desired outliers id df_new1:

# %% [markdown]
# Model without outliers is df and model with desired outliers id df_new1:

# %%
#independent column

x=df_new.iloc[:,:-1]
#target
y=df_new.iloc[:,-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5848/423970678.py in <module>
#       1 #independent column
# ----> 2 x=df_new.iloc[:,:-1]
#       3 #target
#       4 y=df_new.iloc[:,-1]
#
# NameError: name 'df_new' is not defined

# %% [markdown]
# Transforming data to remove skewness:

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5848/875779114.py in <module>
#       1 from sklearn.preprocessing import power_transform
# ----> 2 x=power_transform(x,method='yeo-johnson')
#       3 x
#
# NameError: name 'x' is not defined

# %%
pd.DataFrame(x).skew()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5848/2728099696.py in <module>
# ----> 1 pd.DataFrame(x).skew()
#
# NameError: name 'x' is not defined

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_trandform(x)
x
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5848/2906816944.py in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc=StandardScaler()
# ----> 3 x=sc.fit_trandform(x)
#       4 x
#
# AttributeError: 'StandardScaler' object has no attribute 'fit_trandform'

# %% [markdown]
# # Outcome has two variables we use Classification Model:

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import logisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5848/3829429286.py in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 from sklearn.linear_model import logisticRegression
#       3 lr=LogisticRegression()
#       4 from sklearn.metrics import accuracy_score
#
# ImportError: cannot import name 'logisticRegression' from 'sklearn.linear_model' (F:\computer\lib\site-packages\sklearn\linear_model\__init__.py)

# %% [markdown]
# # Splitting the dataframe:

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.preduct(x_train)
    pred_test=lr.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5848/1820178218.py in <module>
#       1 for i in range(0,1000):
# ----> 2     x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
#       3     lr.fit(x_train,y_train)
#       4     pred_train=lr.preduct(x_train)
#       5     pred_test=lr.predict(x_test)
#
# NameError: name 'x' is not defined
